# %%
# POJO for Trade Order

from dataclasses import dataclass, asdict, field
from datetime import datetime
import json
import uuid

@dataclass
class TradeOrder:
    stock_name: str
    price: float
    quantity: int
    name: str
    type: str
    order_id : str
    valid_till: str
    timestamp: str

    def __post_init__(self):
        
        if not isinstance(self.stock_name, str) or len(self.stock_name) == 0:
            raise ValueError("Invalid stock name; it must be a non-empty string.")
        
        if not isinstance(self.price, (float, int)) or self.price <= 0:
            raise ValueError("Invalid price; it must be a positive number.")
        
        if not isinstance(self.quantity, int) or self.quantity <= 0:
            raise ValueError("Invalid quantity; it must be a positive integer.")
        
        if not isinstance(self.name, str) or len(self.name) == 0:
            raise ValueError("Invalid name; it must be a non-empty string.")

        # Validate type field as either 'buy' or 'sell'
        if self.type not in ["buy", "sell"]:
            raise ValueError("Invalid type; it must be 'buy' or 'sell'.")

        try:
            valid_till_dt = datetime.strptime(self.valid_till, '%Y-%m-%d %H:%M:%S')
            if valid_till_dt <= datetime.now():
                raise ValueError("Invalid 'valid_till' datetime; it must be in the future.")
        except ValueError:
            raise ValueError("Invalid 'valid_till' format; expected format is 'YYYY-MM-DD HH:MM:SS'.")

        try:
            datetime.strptime(self.timestamp, '%Y-%m-%d %H:%M:%S')
        except ValueError:
            raise ValueError("Invalid 'timestamp' format; expected format is 'YYYY-MM-DD HH:MM:SS'.")
    
    def to_json(self):
        return json.dumps(asdict(self))
    
    @staticmethod
    def from_json(data):
        data = json.loads(data)
        return TradeOrder(**data)

# %%
# Array of 25 company stock symbols

symbols = [
    "AAPL",  # Apple
    "MSFT",  # Microsoft
    "GOOGL", # Alphabet (Google)
    "AMZN",  # Amazon
    "TSLA",  # Tesla
    "NVDA",  # NVIDIA
    "META",  # Meta Platforms (formerly Facebook)
    "BRK-B", # Berkshire Hathaway
    "JPM",   # JPMorgan Chase
    "V",     # Visa
    "PG",    # Procter & Gamble
    "UNH",   # UnitedHealth Group
    "JNJ",   # Johnson & Johnson
    "WMT",   # Walmart
    "MA",    # Mastercard
    "DIS",   # Walt Disney
    "PYPL",  # PayPal
    "HD",    # Home Depot
    "BAC",   # Bank of America
    "XOM",   # ExxonMobil
    "CVX",   # Chevron
    "LLY",   # Eli Lilly
    "ABT",   # Abbott Laboratories
    "CRM",   # Salesforce
    "KO",    # Coca-Cola
]

# %%
# Array of 100 names

names = ["Alice", "Bob", "Charlie", "David", "Emily", "Frank", "Grace", "Henry", "Isabella", "Jack",
               "Kelly", "Larry", "Michelle", "Nathan", "Olivia", "Patrick", "Quinn", "Rachel", "Samuel", "Thomas",
               "Ursula", "Victor", "Wendy", "Xavier", "Yasmin", "Zachary", "Abigail", "Benjamin", "Chloe", "Daniel",
               "Eleanor", "Finn", "Gabriella", "Harry", "Iris", "James", "Katherine", "Leo", "Maya", "Noah",
               "Olivia", "Paul", "Quinn", "Riley", "Sarah", "Thomas", "Uma", "Vincent", "Willow", "Xavier",
               "Yasmin", "Zachary", "Abigail", "Benjamin", "Chloe", "Daniel", "Eleanor", "Finn", "Gabriella", "Harry",
               "Iris", "James", "Katherine", "Leo", "Maya", "Noah", "Olivia", "Paul", "Quinn", "Riley",
               "Sarah", "Thomas", "Uma", "Vincent", "Willow", "Xavier", "Yasmin", "Zachary"]

# %%
# Order Type
order_types = ['buy', 'sell']

# %%
# Persists generated topics to csv

import os
import csv


def write_order_to_csv(order, file_path='trade_orders.csv'):
    # Check if the file exists to write header only once
    file_exists = os.path.isfile(file_path)
    
    with open(file_path, mode='a', newline='') as file:
        writer = csv.writer(file)
        
        # Write header if file does not exist
        if not file_exists:
            writer.writerow(['stock_name', 'price', 'quantity', 'name', 'type', 'order_id','valid_till', 'timestamp'])
        
        # Write the order data as a row
        writer.writerow([
            order.stock_name,
            order.price,
            order.quantity,
            order.name,
            order.type,
            order.order_id,
            order.valid_till,
            order.timestamp
            
        ])
    print(f"Trade order saved to CSV: {order}")

# %%
# kafka_stock_producer_with_matching.py
from kafka import KafkaProducer
from kafka.errors import KafkaError
import random
from datetime import datetime, timedelta
import time
from kafka import KafkaConsumer
from kafka.admin import KafkaAdminClient, NewTopic


MATCH_PROBABILITY = 0.7  # 70% probability of matching orders
unmatched_orders = []    # Queue to store unmatched orders

group_id = 'stock_trade_consumer_group'  # Define the group ID here
topic_name = 'orders'

def create_kafka_topic(topic_name, num_partitions, replication_factor=1):
    admin_client = KafkaAdminClient(bootstrap_servers='localhost:9092',api_version=(0,11,5))
    topic = NewTopic(name=topic_name, num_partitions=num_partitions, replication_factor=replication_factor)
    
    try:
        admin_client.create_topics([topic])
        print(f"Topic '{topic_name}' created with {num_partitions} partitions.")
    except Exception as e:
        print(f"Failed to create topic: {e}")
    finally:
        admin_client.close()

# Example usage
#create_kafka_topic(topic_name_buyer, num_partitions=3)
#create_kafka_topic(topic_name_seller, num_partitions=3)
create_kafka_topic(topic_name, num_partitions=2)
# Out:
# Topic 'orders' created with 2 partitions.

# %%
# Define a function for serializing the value
def json_serializer(data):
    # If the data is already a string, just encode it
    if isinstance(data, str):
        return data.encode('utf-8')
    # Otherwise, convert the dictionary to a JSON string and then encode it
    return json.dumps(data).encode('utf-8')

# %%
def create_kafka_producer():
    return KafkaProducer(
        bootstrap_servers=['localhost:9092'],
        api_version=(0,11,5),
        value_serializer=lambda v: v.to_json().encode('utf-8'),
        key_serializer=lambda v: v.encode('utf-8') if isinstance(v, str) else json.dumps(v).encode('utf-8'),
        retries=5
    )

# %%
def generate_random_order():
    stock_name = random.choice(symbols)
    price = round(random.uniform(100, 1500), 2)
    quantity = random.randint(1, 100)
    name = random.choice(names)
    order_type = random.choice(order_types)
    order_id = str(uuid.uuid4())  # Generates a GUID in string format
    valid_till = (datetime.now() + timedelta(days=random.randint(1, 5))).strftime('%Y-%m-%d %H:%M:%S')
    timestamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')

    return TradeOrder(stock_name, price, quantity, name, order_type, order_id, valid_till, timestamp)

# %%
def generate_matching_order(order):
    # Create a matching order with the opposite type
    opposite_type = 'sell' if order.type == 'buy' else 'buy'
    return TradeOrder(
        stock_name=order.stock_name,
        price=order.price,
        quantity=order.quantity,
        name=random.choice(names),
        type=opposite_type,
        order_id = order.order_id,
        valid_till=order.valid_till,
        timestamp=order.timestamp
    )

# %%
def generate_trade_order():
    # Generate a new random order
    new_order = generate_random_order()

    # 70% chance of creating a matching order
    if random.random() < MATCH_PROBABILITY:
        matching_order = generate_matching_order(new_order)
        return [new_order, matching_order]

    # If no match, just return the new order as unmatched
    unmatched_orders.append(new_order)
    return [new_order]

# %%
def send_trade_order(producer, topic, order):
    try:
        #future = producer.send(topic, order)
        index_of_stock = symbols.index(order.stock_name)

        if index_of_stock < 10:
            partition = 0
        else:
            partition = 1
        future = producer.send(topic, key=order.order_id, value=order,partition=partition)
        result = future.get(timeout=10)
        print(f"Trade order sent to {topic}: {order}")
        print(f"Processing trade order: {order}")
        #write_order_to_csv(order)
    except KafkaError as e:
        print(f"Failed to send trade order: {order}, Error: {e}")
    finally:
        producer.flush()

# %%
if __name__ == "__main__":
    
    producer = create_kafka_producer()
    
    try:
        while True:
            orders = generate_trade_order()
            for order in orders:
                print(order.stock_name)
                send_trade_order(producer, topic_name, order)
            time.sleep(10)
    except KeyboardInterrupt:
        print("Stopping producer.")
    finally:
        producer.close()
# Out:
# AAPL
# Trade order sent to orders: TradeOrder(stock_name='AAPL', price=1262.01, quantity=34, name='Uma', type='sell', order_id='ddf72781-c6be-4138-a6ad-a7a221058c01', valid_till='2024-11-20 23:55:04', timestamp='2024-11-17 23:55:04')
# Processing trade order: TradeOrder(stock_name='AAPL', price=1262.01, quantity=34, name='Uma', type='sell', order_id='ddf72781-c6be-4138-a6ad-a7a221058c01', valid_till='2024-11-20 23:55:04', timestamp='2024-11-17 23:55:04')
# V
# Trade order sent to orders: TradeOrder(stock_name='V', price=947.97, quantity=14, name='Benjamin', type='sell', order_id='9bc0aaf1-e8ec-45bc-ad3e-7d7ac948ab07', valid_till='2024-11-19 23:55:14', timestamp='2024-11-17 23:55:14')
# Processing trade order: TradeOrder(stock_name='V', price=947.97, quantity=14, name='Benjamin', type='sell', order_id='9bc0aaf1-e8ec-45bc-ad3e-7d7ac948ab07', valid_till='2024-11-19 23:55:14', timestamp='2024-11-17 23:55:14')
# V
# Trade order sent to orders: TradeOrder(stock_name='V', price=978.6, quantity=8, name='Willow', type='sell', order_id='85330869-1cf7-4baa-a297-f0dc157d1009', valid_till='2024-11-19 23:55:24', timestamp='2024-11-17 23:55:24')
# Processing trade order: TradeOrder(stock_name='V', price=978.6, quantity=8, name='Willow', type='sell', order_id='85330869-1cf7-4baa-a297-f0dc157d1009', valid_till='2024-11-19 23:55:24', timestamp='2024-11-17 23:55:24')
# LLY
# Trade order sent to orders: TradeOrder(stock_name='LLY', price=773.24, quantity=8, name='Iris', type='buy', order_id='b3f21c11-35bf-4e58-9b15-10053b8ec349', valid_till='2024-11-21 23:55:34', timestamp='2024-11-17 23:55:34')
# Processing trade order: TradeOrder(stock_name='LLY', price=773.24, quantity=8, name='Iris', type='buy', order_id='b3f21c11-35bf-4e58-9b15-10053b8ec349', valid_till='2024-11-21 23:55:34', timestamp='2024-11-17 23:55:34')
# LLY
# Trade order sent to orders: TradeOrder(stock_name='LLY', price=773.24, quantity=8, name='Chloe', type='sell', order_id='b3f21c11-35bf-4e58-9b15-10053b8ec349', valid_till='2024-11-21 23:55:34', timestamp='2024-11-17 23:55:34')
# Processing trade order: TradeOrder(stock_name='LLY', price=773.24, quantity=8, name='Chloe', type='sell', order_id='b3f21c11-35bf-4e58-9b15-10053b8ec349', valid_till='2024-11-21 23:55:34', timestamp='2024-11-17 23:55:34')
# META
# Trade order sent to orders: TradeOrder(stock_name='META', price=620.88, quantity=64, name='Alice', type='sell', order_id='ee14a5ec-4890-457f-91ff-1ef1c2ab4db6', valid_till='2024-11-21 23:55:44', timestamp='2024-11-17 23:55:44')
# Processing trade order: TradeOrder(stock_name='META', price=620.88, quantity=64, name='Alice', type='sell', order_id='ee14a5ec-4890-457f-91ff-1ef1c2ab4db6', valid_till='2024-11-21 23:55:44', timestamp='2024-11-17 23:55:44')
# META
# Trade order sent to orders: TradeOrder(stock_name='META', price=620.88, quantity=64, name='Chloe', type='buy', order_id='ee14a5ec-4890-457f-91ff-1ef1c2ab4db6', valid_till='2024-11-21 23:55:44', timestamp='2024-11-17 23:55:44')
# Processing trade order: TradeOrder(stock_name='META', price=620.88, quantity=64, name='Chloe', type='buy', order_id='ee14a5ec-4890-457f-91ff-1ef1c2ab4db6', valid_till='2024-11-21 23:55:44', timestamp='2024-11-17 23:55:44')
# WMT
# Trade order sent to orders: TradeOrder(stock_name='WMT', price=1196.82, quantity=15, name='Riley', type='sell', order_id='81ab3ea2-ad8c-469a-a7a8-34f2dcbf075f', valid_till='2024-11-18 23:55:54', timestamp='2024-11-17 23:55:54')
# Processing trade order: TradeOrder(stock_name='WMT', price=1196.82, quantity=15, name='Riley', type='sell', order_id='81ab3ea2-ad8c-469a-a7a8-34f2dcbf075f', valid_till='2024-11-18 23:55:54', timestamp='2024-11-17 23:55:54')
# WMT
# Trade order sent to orders: TradeOrder(stock_name='WMT', price=1196.82, quantity=15, name='Quinn', type='buy', order_id='81ab3ea2-ad8c-469a-a7a8-34f2dcbf075f', valid_till='2024-11-18 23:55:54', timestamp='2024-11-17 23:55:54')
# Processing trade order: TradeOrder(stock_name='WMT', price=1196.82, quantity=15, name='Quinn', type='buy', order_id='81ab3ea2-ad8c-469a-a7a8-34f2dcbf075f', valid_till='2024-11-18 23:55:54', timestamp='2024-11-17 23:55:54')
# MA
# Trade order sent to orders: TradeOrder(stock_name='MA', price=1029.86, quantity=18, name='Isabella', type='sell', order_id='85a1449a-d502-4703-8ba3-3ea46ac3c1c1', valid_till='2024-11-18 23:56:04', timestamp='2024-11-17 23:56:04')
# Processing trade order: TradeOrder(stock_name='MA', price=1029.86, quantity=18, name='Isabella', type='sell', order_id='85a1449a-d502-4703-8ba3-3ea46ac3c1c1', valid_till='2024-11-18 23:56:04', timestamp='2024-11-17 23:56:04')
# MA
# Trade order sent to orders: TradeOrder(stock_name='MA', price=1029.86, quantity=18, name='Zachary', type='buy', order_id='85a1449a-d502-4703-8ba3-3ea46ac3c1c1', valid_till='2024-11-18 23:56:04', timestamp='2024-11-17 23:56:04')
# Processing trade order: TradeOrder(stock_name='MA', price=1029.86, quantity=18, name='Zachary', type='buy', order_id='85a1449a-d502-4703-8ba3-3ea46ac3c1c1', valid_till='2024-11-18 23:56:04', timestamp='2024-11-17 23:56:04')
# BRK-B
# Trade order sent to orders: TradeOrder(stock_name='BRK-B', price=1391.72, quantity=31, name='James', type='buy', order_id='785bb3c1-277e-458e-8e0d-28cc7e24d8fe', valid_till='2024-11-20 23:56:14', timestamp='2024-11-17 23:56:14')
# Processing trade order: TradeOrder(stock_name='BRK-B', price=1391.72, quantity=31, name='James', type='buy', order_id='785bb3c1-277e-458e-8e0d-28cc7e24d8fe', valid_till='2024-11-20 23:56:14', timestamp='2024-11-17 23:56:14')
# BRK-B
# Trade order sent to orders: TradeOrder(stock_name='BRK-B', price=1391.72, quantity=31, name='Vincent', type='sell', order_id='785bb3c1-277e-458e-8e0d-28cc7e24d8fe', valid_till='2024-11-20 23:56:14', timestamp='2024-11-17 23:56:14')
# Processing trade order: TradeOrder(stock_name='BRK-B', price=1391.72, quantity=31, name='Vincent', type='sell', order_id='785bb3c1-277e-458e-8e0d-28cc7e24d8fe', valid_till='2024-11-20 23:56:14', timestamp='2024-11-17 23:56:14')
# BRK-B
# Trade order sent to orders: TradeOrder(stock_name='BRK-B', price=1481.34, quantity=99, name='Alice', type='buy', order_id='bafa7b55-1cee-400c-9c34-8175616f178d', valid_till='2024-11-19 23:56:24', timestamp='2024-11-17 23:56:24')
# Processing trade order: TradeOrder(stock_name='BRK-B', price=1481.34, quantity=99, name='Alice', type='buy', order_id='bafa7b55-1cee-400c-9c34-8175616f178d', valid_till='2024-11-19 23:56:24', timestamp='2024-11-17 23:56:24')
# AMZN
# Trade order sent to orders: TradeOrder(stock_name='AMZN', price=1423.76, quantity=24, name='Harry', type='sell', order_id='53c2a130-f524-4cd0-af7b-8f3a903af93f', valid_till='2024-11-20 23:56:34', timestamp='2024-11-17 23:56:34')
# Processing trade order: TradeOrder(stock_name='AMZN', price=1423.76, quantity=24, name='Harry', type='sell', order_id='53c2a130-f524-4cd0-af7b-8f3a903af93f', valid_till='2024-11-20 23:56:34', timestamp='2024-11-17 23:56:34')
# PYPL
# Trade order sent to orders: TradeOrder(stock_name='PYPL', price=976.39, quantity=29, name='Wendy', type='buy', order_id='3f55a742-6494-4cf6-b768-d152d5527791', valid_till='2024-11-19 23:56:44', timestamp='2024-11-17 23:56:44')
# Processing trade order: TradeOrder(stock_name='PYPL', price=976.39, quantity=29, name='Wendy', type='buy', order_id='3f55a742-6494-4cf6-b768-d152d5527791', valid_till='2024-11-19 23:56:44', timestamp='2024-11-17 23:56:44')
# PYPL
# Trade order sent to orders: TradeOrder(stock_name='PYPL', price=976.39, quantity=29, name='Larry', type='sell', order_id='3f55a742-6494-4cf6-b768-d152d5527791', valid_till='2024-11-19 23:56:44', timestamp='2024-11-17 23:56:44')
# Processing trade order: TradeOrder(stock_name='PYPL', price=976.39, quantity=29, name='Larry', type='sell', order_id='3f55a742-6494-4cf6-b768-d152d5527791', valid_till='2024-11-19 23:56:44', timestamp='2024-11-17 23:56:44')
# AMZN
# Trade order sent to orders: TradeOrder(stock_name='AMZN', price=324.62, quantity=36, name='Yasmin', type='sell', order_id='2b736fdd-cfb0-4a0f-9038-c6d8499df3c0', valid_till='2024-11-20 23:56:54', timestamp='2024-11-17 23:56:54')
# Processing trade order: TradeOrder(stock_name='AMZN', price=324.62, quantity=36, name='Yasmin', type='sell', order_id='2b736fdd-cfb0-4a0f-9038-c6d8499df3c0', valid_till='2024-11-20 23:56:54', timestamp='2024-11-17 23:56:54')
# MA
# Trade order sent to orders: TradeOrder(stock_name='MA', price=601.03, quantity=27, name='Leo', type='sell', order_id='147ce456-b594-443b-a029-afe70f2142de', valid_till='2024-11-22 23:57:04', timestamp='2024-11-17 23:57:04')
# Processing trade order: TradeOrder(stock_name='MA', price=601.03, quantity=27, name='Leo', type='sell', order_id='147ce456-b594-443b-a029-afe70f2142de', valid_till='2024-11-22 23:57:04', timestamp='2024-11-17 23:57:04')
# KO
# Trade order sent to orders: TradeOrder(stock_name='KO', price=1139.62, quantity=6, name='Daniel', type='buy', order_id='f64153d0-b29a-4602-ad38-24c8d5014fc4', valid_till='2024-11-22 23:57:14', timestamp='2024-11-17 23:57:14')
# Processing trade order: TradeOrder(stock_name='KO', price=1139.62, quantity=6, name='Daniel', type='buy', order_id='f64153d0-b29a-4602-ad38-24c8d5014fc4', valid_till='2024-11-22 23:57:14', timestamp='2024-11-17 23:57:14')
# KO
# Trade order sent to orders: TradeOrder(stock_name='KO', price=1139.62, quantity=6, name='Harry', type='sell', order_id='f64153d0-b29a-4602-ad38-24c8d5014fc4', valid_till='2024-11-22 23:57:14', timestamp='2024-11-17 23:57:14')
# Processing trade order: TradeOrder(stock_name='KO', price=1139.62, quantity=6, name='Harry', type='sell', order_id='f64153d0-b29a-4602-ad38-24c8d5014fc4', valid_till='2024-11-22 23:57:14', timestamp='2024-11-17 23:57:14')
# AAPL
# Trade order sent to orders: TradeOrder(stock_name='AAPL', price=698.05, quantity=67, name='Uma', type='buy', order_id='8949b029-a7b5-4aa6-871a-92808f6a982a', valid_till='2024-11-20 23:57:24', timestamp='2024-11-17 23:57:24')
# Processing trade order: TradeOrder(stock_name='AAPL', price=698.05, quantity=67, name='Uma', type='buy', order_id='8949b029-a7b5-4aa6-871a-92808f6a982a', valid_till='2024-11-20 23:57:24', timestamp='2024-11-17 23:57:24')
# CRM
# Trade order sent to orders: TradeOrder(stock_name='CRM', price=1170.59, quantity=74, name='Jack', type='sell', order_id='2af25b49-dd08-4d77-8a24-629bee449ffb', valid_till='2024-11-18 23:57:34', timestamp='2024-11-17 23:57:34')
# Processing trade order: TradeOrder(stock_name='CRM', price=1170.59, quantity=74, name='Jack', type='sell', order_id='2af25b49-dd08-4d77-8a24-629bee449ffb', valid_till='2024-11-18 23:57:34', timestamp='2024-11-17 23:57:34')
# UNH
# Trade order sent to orders: TradeOrder(stock_name='UNH', price=416.94, quantity=67, name='Frank', type='buy', order_id='2b636427-4ea6-4a8b-9a27-4af95aa202e4', valid_till='2024-11-20 23:57:44', timestamp='2024-11-17 23:57:44')
# Processing trade order: TradeOrder(stock_name='UNH', price=416.94, quantity=67, name='Frank', type='buy', order_id='2b636427-4ea6-4a8b-9a27-4af95aa202e4', valid_till='2024-11-20 23:57:44', timestamp='2024-11-17 23:57:44')
# UNH
# Trade order sent to orders: TradeOrder(stock_name='UNH', price=416.94, quantity=67, name='Wendy', type='sell', order_id='2b636427-4ea6-4a8b-9a27-4af95aa202e4', valid_till='2024-11-20 23:57:44', timestamp='2024-11-17 23:57:44')
# Processing trade order: TradeOrder(stock_name='UNH', price=416.94, quantity=67, name='Wendy', type='sell', order_id='2b636427-4ea6-4a8b-9a27-4af95aa202e4', valid_till='2024-11-20 23:57:44', timestamp='2024-11-17 23:57:44')
# BAC
# Trade order sent to orders: TradeOrder(stock_name='BAC', price=904.67, quantity=32, name='Wendy', type='sell', order_id='cd637605-8736-4614-8cf6-e536bfae8c38', valid_till='2024-11-19 23:57:54', timestamp='2024-11-17 23:57:54')
# Processing trade order: TradeOrder(stock_name='BAC', price=904.67, quantity=32, name='Wendy', type='sell', order_id='cd637605-8736-4614-8cf6-e536bfae8c38', valid_till='2024-11-19 23:57:54', timestamp='2024-11-17 23:57:54')
# BAC
# Trade order sent to orders: TradeOrder(stock_name='BAC', price=904.67, quantity=32, name='Chloe', type='buy', order_id='cd637605-8736-4614-8cf6-e536bfae8c38', valid_till='2024-11-19 23:57:54', timestamp='2024-11-17 23:57:54')
# Processing trade order: TradeOrder(stock_name='BAC', price=904.67, quantity=32, name='Chloe', type='buy', order_id='cd637605-8736-4614-8cf6-e536bfae8c38', valid_till='2024-11-19 23:57:54', timestamp='2024-11-17 23:57:54')
# GOOGL
# Trade order sent to orders: TradeOrder(stock_name='GOOGL', price=1344.67, quantity=62, name='Katherine', type='sell', order_id='18987329-6031-4be1-be9a-c5c84152f350', valid_till='2024-11-21 23:58:04', timestamp='2024-11-17 23:58:04')
# Processing trade order: TradeOrder(stock_name='GOOGL', price=1344.67, quantity=62, name='Katherine', type='sell', order_id='18987329-6031-4be1-be9a-c5c84152f350', valid_till='2024-11-21 23:58:04', timestamp='2024-11-17 23:58:04')
# MA
# Trade order sent to orders: TradeOrder(stock_name='MA', price=309.05, quantity=24, name='Abigail', type='sell', order_id='73219114-90e8-4230-87ac-a2889c549d1c', valid_till='2024-11-20 23:58:14', timestamp='2024-11-17 23:58:14')
# Processing trade order: TradeOrder(stock_name='MA', price=309.05, quantity=24, name='Abigail', type='sell', order_id='73219114-90e8-4230-87ac-a2889c549d1c', valid_till='2024-11-20 23:58:14', timestamp='2024-11-17 23:58:14')
# MA
# Trade order sent to orders: TradeOrder(stock_name='MA', price=309.05, quantity=24, name='Larry', type='buy', order_id='73219114-90e8-4230-87ac-a2889c549d1c', valid_till='2024-11-20 23:58:14', timestamp='2024-11-17 23:58:14')
# Processing trade order: TradeOrder(stock_name='MA', price=309.05, quantity=24, name='Larry', type='buy', order_id='73219114-90e8-4230-87ac-a2889c549d1c', valid_till='2024-11-20 23:58:14', timestamp='2024-11-17 23:58:14')
# XOM
# Trade order sent to orders: TradeOrder(stock_name='XOM', price=1095.91, quantity=89, name='Leo', type='sell', order_id='f2e07db1-fd7a-4f0c-b8aa-3f0096db43f8', valid_till='2024-11-20 23:58:24', timestamp='2024-11-17 23:58:24')
# Processing trade order: TradeOrder(stock_name='XOM', price=1095.91, quantity=89, name='Leo', type='sell', order_id='f2e07db1-fd7a-4f0c-b8aa-3f0096db43f8', valid_till='2024-11-20 23:58:24', timestamp='2024-11-17 23:58:24')
# XOM
# Trade order sent to orders: TradeOrder(stock_name='XOM', price=1095.91, quantity=89, name='Riley', type='buy', order_id='f2e07db1-fd7a-4f0c-b8aa-3f0096db43f8', valid_till='2024-11-20 23:58:24', timestamp='2024-11-17 23:58:24')
# Processing trade order: TradeOrder(stock_name='XOM', price=1095.91, quantity=89, name='Riley', type='buy', order_id='f2e07db1-fd7a-4f0c-b8aa-3f0096db43f8', valid_till='2024-11-20 23:58:24', timestamp='2024-11-17 23:58:24')
# LLY
# Trade order sent to orders: TradeOrder(stock_name='LLY', price=311.6, quantity=86, name='Iris', type='sell', order_id='f1cb5ab1-f163-4b99-be6e-7c9773a7ed53', valid_till='2024-11-19 23:58:34', timestamp='2024-11-17 23:58:34')
# Processing trade order: TradeOrder(stock_name='LLY', price=311.6, quantity=86, name='Iris', type='sell', order_id='f1cb5ab1-f163-4b99-be6e-7c9773a7ed53', valid_till='2024-11-19 23:58:34', timestamp='2024-11-17 23:58:34')
# LLY
# Trade order sent to orders: TradeOrder(stock_name='LLY', price=1455.78, quantity=92, name='Uma', type='buy', order_id='fea591ee-5588-470e-9dd7-69af778aa5a7', valid_till='2024-11-18 23:58:44', timestamp='2024-11-17 23:58:44')
# Processing trade order: TradeOrder(stock_name='LLY', price=1455.78, quantity=92, name='Uma', type='buy', order_id='fea591ee-5588-470e-9dd7-69af778aa5a7', valid_till='2024-11-18 23:58:44', timestamp='2024-11-17 23:58:44')
# LLY
# Trade order sent to orders: TradeOrder(stock_name='LLY', price=1455.78, quantity=92, name='Benjamin', type='sell', order_id='fea591ee-5588-470e-9dd7-69af778aa5a7', valid_till='2024-11-18 23:58:44', timestamp='2024-11-17 23:58:44')
# Processing trade order: TradeOrder(stock_name='LLY', price=1455.78, quantity=92, name='Benjamin', type='sell', order_id='fea591ee-5588-470e-9dd7-69af778aa5a7', valid_till='2024-11-18 23:58:44', timestamp='2024-11-17 23:58:44')
# CVX
# Trade order sent to orders: TradeOrder(stock_name='CVX', price=102.35, quantity=16, name='Grace', type='buy', order_id='6de0fe9a-8225-42dd-bd73-e70f4302184a', valid_till='2024-11-18 23:58:54', timestamp='2024-11-17 23:58:54')
# Processing trade order: TradeOrder(stock_name='CVX', price=102.35, quantity=16, name='Grace', type='buy', order_id='6de0fe9a-8225-42dd-bd73-e70f4302184a', valid_till='2024-11-18 23:58:54', timestamp='2024-11-17 23:58:54')
# V
# Trade order sent to orders: TradeOrder(stock_name='V', price=948.31, quantity=92, name='Yasmin', type='buy', order_id='2cb75622-83a5-4fa6-aefd-0a4256b673a1', valid_till='2024-11-18 23:59:04', timestamp='2024-11-17 23:59:04')
# Processing trade order: TradeOrder(stock_name='V', price=948.31, quantity=92, name='Yasmin', type='buy', order_id='2cb75622-83a5-4fa6-aefd-0a4256b673a1', valid_till='2024-11-18 23:59:04', timestamp='2024-11-17 23:59:04')
# MA
# Trade order sent to orders: TradeOrder(stock_name='MA', price=1047.54, quantity=12, name='Yasmin', type='buy', order_id='7d4d5ac6-134d-412d-988b-c28a108bf1ff', valid_till='2024-11-22 23:59:14', timestamp='2024-11-17 23:59:14')
# Processing trade order: TradeOrder(stock_name='MA', price=1047.54, quantity=12, name='Yasmin', type='buy', order_id='7d4d5ac6-134d-412d-988b-c28a108bf1ff', valid_till='2024-11-22 23:59:14', timestamp='2024-11-17 23:59:14')
# MA
# Trade order sent to orders: TradeOrder(stock_name='MA', price=1047.54, quantity=12, name='Ursula', type='sell', order_id='7d4d5ac6-134d-412d-988b-c28a108bf1ff', valid_till='2024-11-22 23:59:14', timestamp='2024-11-17 23:59:14')
# Processing trade order: TradeOrder(stock_name='MA', price=1047.54, quantity=12, name='Ursula', type='sell', order_id='7d4d5ac6-134d-412d-988b-c28a108bf1ff', valid_till='2024-11-22 23:59:14', timestamp='2024-11-17 23:59:14')
# MSFT
# Trade order sent to orders: TradeOrder(stock_name='MSFT', price=284.86, quantity=41, name='Wendy', type='sell', order_id='e542072b-f912-4640-a601-166727c78754', valid_till='2024-11-21 23:59:24', timestamp='2024-11-17 23:59:24')
# Processing trade order: TradeOrder(stock_name='MSFT', price=284.86, quantity=41, name='Wendy', type='sell', order_id='e542072b-f912-4640-a601-166727c78754', valid_till='2024-11-21 23:59:24', timestamp='2024-11-17 23:59:24')
# MSFT
# Trade order sent to orders: TradeOrder(stock_name='MSFT', price=284.86, quantity=41, name='Chloe', type='buy', order_id='e542072b-f912-4640-a601-166727c78754', valid_till='2024-11-21 23:59:24', timestamp='2024-11-17 23:59:24')
# Processing trade order: TradeOrder(stock_name='MSFT', price=284.86, quantity=41, name='Chloe', type='buy', order_id='e542072b-f912-4640-a601-166727c78754', valid_till='2024-11-21 23:59:24', timestamp='2024-11-17 23:59:24')
# GOOGL
# Trade order sent to orders: TradeOrder(stock_name='GOOGL', price=379.37, quantity=41, name='David', type='buy', order_id='f590c542-9729-4e3a-98e3-6f7bbeaa34a8', valid_till='2024-11-21 23:59:34', timestamp='2024-11-17 23:59:34')
# Processing trade order: TradeOrder(stock_name='GOOGL', price=379.37, quantity=41, name='David', type='buy', order_id='f590c542-9729-4e3a-98e3-6f7bbeaa34a8', valid_till='2024-11-21 23:59:34', timestamp='2024-11-17 23:59:34')
# GOOGL
# Trade order sent to orders: TradeOrder(stock_name='GOOGL', price=379.37, quantity=41, name='Victor', type='sell', order_id='f590c542-9729-4e3a-98e3-6f7bbeaa34a8', valid_till='2024-11-21 23:59:34', timestamp='2024-11-17 23:59:34')
# Processing trade order: TradeOrder(stock_name='GOOGL', price=379.37, quantity=41, name='Victor', type='sell', order_id='f590c542-9729-4e3a-98e3-6f7bbeaa34a8', valid_till='2024-11-21 23:59:34', timestamp='2024-11-17 23:59:34')
# KO
# Trade order sent to orders: TradeOrder(stock_name='KO', price=218.51, quantity=44, name='Abigail', type='buy', order_id='0337e4e5-e461-40e6-b9e1-9a239e919c31', valid_till='2024-11-21 23:59:44', timestamp='2024-11-17 23:59:44')
# Processing trade order: TradeOrder(stock_name='KO', price=218.51, quantity=44, name='Abigail', type='buy', order_id='0337e4e5-e461-40e6-b9e1-9a239e919c31', valid_till='2024-11-21 23:59:44', timestamp='2024-11-17 23:59:44')
# WMT
# Trade order sent to orders: TradeOrder(stock_name='WMT', price=1139.25, quantity=29, name='Thomas', type='buy', order_id='62d7256e-b8b3-4dc5-97d3-c8d51a66199d', valid_till='2024-11-22 23:59:54', timestamp='2024-11-17 23:59:54')
# Processing trade order: TradeOrder(stock_name='WMT', price=1139.25, quantity=29, name='Thomas', type='buy', order_id='62d7256e-b8b3-4dc5-97d3-c8d51a66199d', valid_till='2024-11-22 23:59:54', timestamp='2024-11-17 23:59:54')
# LLY
# Trade order sent to orders: TradeOrder(stock_name='LLY', price=862.11, quantity=34, name='Victor', type='sell', order_id='8d5a8e70-b060-4b25-9891-e03e45529f2a', valid_till='2024-11-20 00:00:04', timestamp='2024-11-18 00:00:04')
# Processing trade order: TradeOrder(stock_name='LLY', price=862.11, quantity=34, name='Victor', type='sell', order_id='8d5a8e70-b060-4b25-9891-e03e45529f2a', valid_till='2024-11-20 00:00:04', timestamp='2024-11-18 00:00:04')
# META
# Trade order sent to orders: TradeOrder(stock_name='META', price=338.88, quantity=21, name='Katherine', type='sell', order_id='b8592ab9-8f8b-46c4-be25-754b0954860c', valid_till='2024-11-21 00:00:14', timestamp='2024-11-18 00:00:14')
# Processing trade order: TradeOrder(stock_name='META', price=338.88, quantity=21, name='Katherine', type='sell', order_id='b8592ab9-8f8b-46c4-be25-754b0954860c', valid_till='2024-11-21 00:00:14', timestamp='2024-11-18 00:00:14')
# AAPL
# Trade order sent to orders: TradeOrder(stock_name='AAPL', price=352.37, quantity=7, name='Thomas', type='sell', order_id='fd4bf930-7f91-463c-bfa6-0d59decfe984', valid_till='2024-11-19 00:00:24', timestamp='2024-11-18 00:00:24')
# Processing trade order: TradeOrder(stock_name='AAPL', price=352.37, quantity=7, name='Thomas', type='sell', order_id='fd4bf930-7f91-463c-bfa6-0d59decfe984', valid_till='2024-11-19 00:00:24', timestamp='2024-11-18 00:00:24')
# TSLA
# Trade order sent to orders: TradeOrder(stock_name='TSLA', price=260.17, quantity=4, name='Chloe', type='sell', order_id='336e1671-ec09-48a4-b15a-7bafc59a7b28', valid_till='2024-11-19 00:00:34', timestamp='2024-11-18 00:00:34')
# Processing trade order: TradeOrder(stock_name='TSLA', price=260.17, quantity=4, name='Chloe', type='sell', order_id='336e1671-ec09-48a4-b15a-7bafc59a7b28', valid_till='2024-11-19 00:00:34', timestamp='2024-11-18 00:00:34')
# TSLA
# Trade order sent to orders: TradeOrder(stock_name='TSLA', price=260.17, quantity=4, name='Harry', type='buy', order_id='336e1671-ec09-48a4-b15a-7bafc59a7b28', valid_till='2024-11-19 00:00:34', timestamp='2024-11-18 00:00:34')
# Processing trade order: TradeOrder(stock_name='TSLA', price=260.17, quantity=4, name='Harry', type='buy', order_id='336e1671-ec09-48a4-b15a-7bafc59a7b28', valid_till='2024-11-19 00:00:34', timestamp='2024-11-18 00:00:34')
# WMT
# Trade order sent to orders: TradeOrder(stock_name='WMT', price=806.93, quantity=12, name='Olivia', type='sell', order_id='a1796929-e82f-4993-b896-56a73969351c', valid_till='2024-11-21 00:00:44', timestamp='2024-11-18 00:00:44')
# Processing trade order: TradeOrder(stock_name='WMT', price=806.93, quantity=12, name='Olivia', type='sell', order_id='a1796929-e82f-4993-b896-56a73969351c', valid_till='2024-11-21 00:00:44', timestamp='2024-11-18 00:00:44')
# WMT
# Trade order sent to orders: TradeOrder(stock_name='WMT', price=806.93, quantity=12, name='Quinn', type='buy', order_id='a1796929-e82f-4993-b896-56a73969351c', valid_till='2024-11-21 00:00:44', timestamp='2024-11-18 00:00:44')
# Processing trade order: TradeOrder(stock_name='WMT', price=806.93, quantity=12, name='Quinn', type='buy', order_id='a1796929-e82f-4993-b896-56a73969351c', valid_till='2024-11-21 00:00:44', timestamp='2024-11-18 00:00:44')
# TSLA
# Trade order sent to orders: TradeOrder(stock_name='TSLA', price=1256.39, quantity=67, name='Zachary', type='buy', order_id='c2f6dc00-d2d7-4fc3-87d1-08b14dd58ae2', valid_till='2024-11-23 00:00:54', timestamp='2024-11-18 00:00:54')
# Processing trade order: TradeOrder(stock_name='TSLA', price=1256.39, quantity=67, name='Zachary', type='buy', order_id='c2f6dc00-d2d7-4fc3-87d1-08b14dd58ae2', valid_till='2024-11-23 00:00:54', timestamp='2024-11-18 00:00:54')
# TSLA
# Trade order sent to orders: TradeOrder(stock_name='TSLA', price=1256.39, quantity=67, name='Yasmin', type='sell', order_id='c2f6dc00-d2d7-4fc3-87d1-08b14dd58ae2', valid_till='2024-11-23 00:00:54', timestamp='2024-11-18 00:00:54')
# Processing trade order: TradeOrder(stock_name='TSLA', price=1256.39, quantity=67, name='Yasmin', type='sell', order_id='c2f6dc00-d2d7-4fc3-87d1-08b14dd58ae2', valid_till='2024-11-23 00:00:54', timestamp='2024-11-18 00:00:54')
# LLY
# Trade order sent to orders: TradeOrder(stock_name='LLY', price=715.31, quantity=3, name='Leo', type='sell', order_id='89c3a1f9-e52f-4b10-99c1-5a8c01120253', valid_till='2024-11-19 00:01:04', timestamp='2024-11-18 00:01:04')
# Processing trade order: TradeOrder(stock_name='LLY', price=715.31, quantity=3, name='Leo', type='sell', order_id='89c3a1f9-e52f-4b10-99c1-5a8c01120253', valid_till='2024-11-19 00:01:04', timestamp='2024-11-18 00:01:04')
# LLY
# Trade order sent to orders: TradeOrder(stock_name='LLY', price=715.31, quantity=3, name='Xavier', type='buy', order_id='89c3a1f9-e52f-4b10-99c1-5a8c01120253', valid_till='2024-11-19 00:01:04', timestamp='2024-11-18 00:01:04')
# Processing trade order: TradeOrder(stock_name='LLY', price=715.31, quantity=3, name='Xavier', type='buy', order_id='89c3a1f9-e52f-4b10-99c1-5a8c01120253', valid_till='2024-11-19 00:01:04', timestamp='2024-11-18 00:01:04')
# V
# Trade order sent to orders: TradeOrder(stock_name='V', price=1032.13, quantity=5, name='Olivia', type='sell', order_id='150c0eb0-b576-4811-9dbb-68c545146a23', valid_till='2024-11-19 00:01:14', timestamp='2024-11-18 00:01:14')
# Processing trade order: TradeOrder(stock_name='V', price=1032.13, quantity=5, name='Olivia', type='sell', order_id='150c0eb0-b576-4811-9dbb-68c545146a23', valid_till='2024-11-19 00:01:14', timestamp='2024-11-18 00:01:14')
# V
# Trade order sent to orders: TradeOrder(stock_name='V', price=1032.13, quantity=5, name='Kelly', type='buy', order_id='150c0eb0-b576-4811-9dbb-68c545146a23', valid_till='2024-11-19 00:01:14', timestamp='2024-11-18 00:01:14')
# Processing trade order: TradeOrder(stock_name='V', price=1032.13, quantity=5, name='Kelly', type='buy', order_id='150c0eb0-b576-4811-9dbb-68c545146a23', valid_till='2024-11-19 00:01:14', timestamp='2024-11-18 00:01:14')
# TSLA
# Trade order sent to orders: TradeOrder(stock_name='TSLA', price=844.17, quantity=65, name='Sarah', type='sell', order_id='fbb7294c-680a-48fd-b255-052cfd4def36', valid_till='2024-11-21 00:01:24', timestamp='2024-11-18 00:01:24')
# Processing trade order: TradeOrder(stock_name='TSLA', price=844.17, quantity=65, name='Sarah', type='sell', order_id='fbb7294c-680a-48fd-b255-052cfd4def36', valid_till='2024-11-21 00:01:24', timestamp='2024-11-18 00:01:24')
# TSLA
# Trade order sent to orders: TradeOrder(stock_name='TSLA', price=844.17, quantity=65, name='Larry', type='buy', order_id='fbb7294c-680a-48fd-b255-052cfd4def36', valid_till='2024-11-21 00:01:24', timestamp='2024-11-18 00:01:24')
# Processing trade order: TradeOrder(stock_name='TSLA', price=844.17, quantity=65, name='Larry', type='buy', order_id='fbb7294c-680a-48fd-b255-052cfd4def36', valid_till='2024-11-21 00:01:24', timestamp='2024-11-18 00:01:24')
# CRM
# Trade order sent to orders: TradeOrder(stock_name='CRM', price=946.13, quantity=26, name='Iris', type='buy', order_id='f48446aa-996d-4552-a4ba-2b92da486062', valid_till='2024-11-23 00:01:34', timestamp='2024-11-18 00:01:34')
# Processing trade order: TradeOrder(stock_name='CRM', price=946.13, quantity=26, name='Iris', type='buy', order_id='f48446aa-996d-4552-a4ba-2b92da486062', valid_till='2024-11-23 00:01:34', timestamp='2024-11-18 00:01:34')
# DIS
# Trade order sent to orders: TradeOrder(stock_name='DIS', price=891.68, quantity=82, name='Nathan', type='buy', order_id='45e5ab96-0fa9-44d8-9a28-ef0153c04348', valid_till='2024-11-22 00:01:44', timestamp='2024-11-18 00:01:44')
# Processing trade order: TradeOrder(stock_name='DIS', price=891.68, quantity=82, name='Nathan', type='buy', order_id='45e5ab96-0fa9-44d8-9a28-ef0153c04348', valid_till='2024-11-22 00:01:44', timestamp='2024-11-18 00:01:44')
# DIS
# Trade order sent to orders: TradeOrder(stock_name='DIS', price=891.68, quantity=82, name='Sarah', type='sell', order_id='45e5ab96-0fa9-44d8-9a28-ef0153c04348', valid_till='2024-11-22 00:01:44', timestamp='2024-11-18 00:01:44')
# Processing trade order: TradeOrder(stock_name='DIS', price=891.68, quantity=82, name='Sarah', type='sell', order_id='45e5ab96-0fa9-44d8-9a28-ef0153c04348', valid_till='2024-11-22 00:01:44', timestamp='2024-11-18 00:01:44')
# PG
# Trade order sent to orders: TradeOrder(stock_name='PG', price=1260.05, quantity=15, name='Larry', type='sell', order_id='f90ec187-febf-4941-a572-ba37b2f3a8dc', valid_till='2024-11-21 00:01:55', timestamp='2024-11-18 00:01:55')
# Processing trade order: TradeOrder(stock_name='PG', price=1260.05, quantity=15, name='Larry', type='sell', order_id='f90ec187-febf-4941-a572-ba37b2f3a8dc', valid_till='2024-11-21 00:01:55', timestamp='2024-11-18 00:01:55')
# PG
# Trade order sent to orders: TradeOrder(stock_name='PG', price=1260.05, quantity=15, name='Harry', type='buy', order_id='f90ec187-febf-4941-a572-ba37b2f3a8dc', valid_till='2024-11-21 00:01:55', timestamp='2024-11-18 00:01:55')
# Processing trade order: TradeOrder(stock_name='PG', price=1260.05, quantity=15, name='Harry', type='buy', order_id='f90ec187-febf-4941-a572-ba37b2f3a8dc', valid_till='2024-11-21 00:01:55', timestamp='2024-11-18 00:01:55')
# UNH
# Trade order sent to orders: TradeOrder(stock_name='UNH', price=1170.83, quantity=89, name='Gabriella', type='sell', order_id='c889fff5-5499-44d4-9d4f-e04dd8d289f4', valid_till='2024-11-20 00:02:05', timestamp='2024-11-18 00:02:05')
# Processing trade order: TradeOrder(stock_name='UNH', price=1170.83, quantity=89, name='Gabriella', type='sell', order_id='c889fff5-5499-44d4-9d4f-e04dd8d289f4', valid_till='2024-11-20 00:02:05', timestamp='2024-11-18 00:02:05')
# JPM
# Trade order sent to orders: TradeOrder(stock_name='JPM', price=539.49, quantity=89, name='Willow', type='sell', order_id='40e042a2-991b-4263-94f4-ea121edd0526', valid_till='2024-11-21 00:02:15', timestamp='2024-11-18 00:02:15')
# Processing trade order: TradeOrder(stock_name='JPM', price=539.49, quantity=89, name='Willow', type='sell', order_id='40e042a2-991b-4263-94f4-ea121edd0526', valid_till='2024-11-21 00:02:15', timestamp='2024-11-18 00:02:15')
# JPM
# Trade order sent to orders: TradeOrder(stock_name='JPM', price=539.49, quantity=89, name='Riley', type='buy', order_id='40e042a2-991b-4263-94f4-ea121edd0526', valid_till='2024-11-21 00:02:15', timestamp='2024-11-18 00:02:15')
# Processing trade order: TradeOrder(stock_name='JPM', price=539.49, quantity=89, name='Riley', type='buy', order_id='40e042a2-991b-4263-94f4-ea121edd0526', valid_till='2024-11-21 00:02:15', timestamp='2024-11-18 00:02:15')
# MA
# Trade order sent to orders: TradeOrder(stock_name='MA', price=497.51, quantity=2, name='Emily', type='sell', order_id='632a68ac-250f-4589-986b-8734d1c37d90', valid_till='2024-11-23 00:02:25', timestamp='2024-11-18 00:02:25')
# Processing trade order: TradeOrder(stock_name='MA', price=497.51, quantity=2, name='Emily', type='sell', order_id='632a68ac-250f-4589-986b-8734d1c37d90', valid_till='2024-11-23 00:02:25', timestamp='2024-11-18 00:02:25')
# MA
# Trade order sent to orders: TradeOrder(stock_name='MA', price=497.51, quantity=2, name='Riley', type='buy', order_id='632a68ac-250f-4589-986b-8734d1c37d90', valid_till='2024-11-23 00:02:25', timestamp='2024-11-18 00:02:25')
# Processing trade order: TradeOrder(stock_name='MA', price=497.51, quantity=2, name='Riley', type='buy', order_id='632a68ac-250f-4589-986b-8734d1c37d90', valid_till='2024-11-23 00:02:25', timestamp='2024-11-18 00:02:25')
# V
# Trade order sent to orders: TradeOrder(stock_name='V', price=182.94, quantity=23, name='Patrick', type='sell', order_id='755e164c-eee6-4929-be72-917cda41df6e', valid_till='2024-11-21 00:02:35', timestamp='2024-11-18 00:02:35')
# Processing trade order: TradeOrder(stock_name='V', price=182.94, quantity=23, name='Patrick', type='sell', order_id='755e164c-eee6-4929-be72-917cda41df6e', valid_till='2024-11-21 00:02:35', timestamp='2024-11-18 00:02:35')
# V
# Trade order sent to orders: TradeOrder(stock_name='V', price=182.94, quantity=23, name='Gabriella', type='buy', order_id='755e164c-eee6-4929-be72-917cda41df6e', valid_till='2024-11-21 00:02:35', timestamp='2024-11-18 00:02:35')
# Processing trade order: TradeOrder(stock_name='V', price=182.94, quantity=23, name='Gabriella', type='buy', order_id='755e164c-eee6-4929-be72-917cda41df6e', valid_till='2024-11-21 00:02:35', timestamp='2024-11-18 00:02:35')
# CVX
# Trade order sent to orders: TradeOrder(stock_name='CVX', price=1406.8, quantity=79, name='Thomas', type='sell', order_id='90dc9cb1-5f9a-4fc0-9d90-33056caa794e', valid_till='2024-11-23 00:02:45', timestamp='2024-11-18 00:02:45')
# Processing trade order: TradeOrder(stock_name='CVX', price=1406.8, quantity=79, name='Thomas', type='sell', order_id='90dc9cb1-5f9a-4fc0-9d90-33056caa794e', valid_till='2024-11-23 00:02:45', timestamp='2024-11-18 00:02:45')
# CVX
# Trade order sent to orders: TradeOrder(stock_name='CVX', price=1406.8, quantity=79, name='Vincent', type='buy', order_id='90dc9cb1-5f9a-4fc0-9d90-33056caa794e', valid_till='2024-11-23 00:02:45', timestamp='2024-11-18 00:02:45')
# Processing trade order: TradeOrder(stock_name='CVX', price=1406.8, quantity=79, name='Vincent', type='buy', order_id='90dc9cb1-5f9a-4fc0-9d90-33056caa794e', valid_till='2024-11-23 00:02:45', timestamp='2024-11-18 00:02:45')
# TSLA
# Trade order sent to orders: TradeOrder(stock_name='TSLA', price=981.96, quantity=78, name='Sarah', type='sell', order_id='4e273656-d4a3-4b87-ac00-aec842d6bf80', valid_till='2024-11-20 00:02:55', timestamp='2024-11-18 00:02:55')
# Processing trade order: TradeOrder(stock_name='TSLA', price=981.96, quantity=78, name='Sarah', type='sell', order_id='4e273656-d4a3-4b87-ac00-aec842d6bf80', valid_till='2024-11-20 00:02:55', timestamp='2024-11-18 00:02:55')
# TSLA
# Trade order sent to orders: TradeOrder(stock_name='TSLA', price=981.96, quantity=78, name='Xavier', type='buy', order_id='4e273656-d4a3-4b87-ac00-aec842d6bf80', valid_till='2024-11-20 00:02:55', timestamp='2024-11-18 00:02:55')
# Processing trade order: TradeOrder(stock_name='TSLA', price=981.96, quantity=78, name='Xavier', type='buy', order_id='4e273656-d4a3-4b87-ac00-aec842d6bf80', valid_till='2024-11-20 00:02:55', timestamp='2024-11-18 00:02:55')
# V
# Trade order sent to orders: TradeOrder(stock_name='V', price=331.15, quantity=96, name='Bob', type='buy', order_id='ee5a979a-bda6-4dbd-b34d-5500a6a952f0', valid_till='2024-11-21 00:03:05', timestamp='2024-11-18 00:03:05')
# Processing trade order: TradeOrder(stock_name='V', price=331.15, quantity=96, name='Bob', type='buy', order_id='ee5a979a-bda6-4dbd-b34d-5500a6a952f0', valid_till='2024-11-21 00:03:05', timestamp='2024-11-18 00:03:05')
# V
# Trade order sent to orders: TradeOrder(stock_name='V', price=331.15, quantity=96, name='Zachary', type='sell', order_id='ee5a979a-bda6-4dbd-b34d-5500a6a952f0', valid_till='2024-11-21 00:03:05', timestamp='2024-11-18 00:03:05')
# Processing trade order: TradeOrder(stock_name='V', price=331.15, quantity=96, name='Zachary', type='sell', order_id='ee5a979a-bda6-4dbd-b34d-5500a6a952f0', valid_till='2024-11-21 00:03:05', timestamp='2024-11-18 00:03:05')
# MA
# Trade order sent to orders: TradeOrder(stock_name='MA', price=1081.86, quantity=94, name='Quinn', type='buy', order_id='6c3436ca-fd08-4bd5-80e7-42366a837fee', valid_till='2024-11-21 00:03:15', timestamp='2024-11-18 00:03:15')
# Processing trade order: TradeOrder(stock_name='MA', price=1081.86, quantity=94, name='Quinn', type='buy', order_id='6c3436ca-fd08-4bd5-80e7-42366a837fee', valid_till='2024-11-21 00:03:15', timestamp='2024-11-18 00:03:15')
# MA
# Trade order sent to orders: TradeOrder(stock_name='MA', price=1081.86, quantity=94, name='Katherine', type='sell', order_id='6c3436ca-fd08-4bd5-80e7-42366a837fee', valid_till='2024-11-21 00:03:15', timestamp='2024-11-18 00:03:15')
# Processing trade order: TradeOrder(stock_name='MA', price=1081.86, quantity=94, name='Katherine', type='sell', order_id='6c3436ca-fd08-4bd5-80e7-42366a837fee', valid_till='2024-11-21 00:03:15', timestamp='2024-11-18 00:03:15')
# CVX
# Trade order sent to orders: TradeOrder(stock_name='CVX', price=155.43, quantity=31, name='Xavier', type='sell', order_id='522d42ba-598c-4ab5-b317-25ecf19b84ce', valid_till='2024-11-19 00:03:25', timestamp='2024-11-18 00:03:25')
# Processing trade order: TradeOrder(stock_name='CVX', price=155.43, quantity=31, name='Xavier', type='sell', order_id='522d42ba-598c-4ab5-b317-25ecf19b84ce', valid_till='2024-11-19 00:03:25', timestamp='2024-11-18 00:03:25')
# MSFT
# Trade order sent to orders: TradeOrder(stock_name='MSFT', price=654.12, quantity=76, name='Victor', type='buy', order_id='36d9448b-c585-4411-ad2e-80325c14b092', valid_till='2024-11-20 00:03:35', timestamp='2024-11-18 00:03:35')
# Processing trade order: TradeOrder(stock_name='MSFT', price=654.12, quantity=76, name='Victor', type='buy', order_id='36d9448b-c585-4411-ad2e-80325c14b092', valid_till='2024-11-20 00:03:35', timestamp='2024-11-18 00:03:35')
# CRM
# Trade order sent to orders: TradeOrder(stock_name='CRM', price=1071.12, quantity=20, name='Willow', type='buy', order_id='00604bc0-8fb4-4712-b75b-c336ab72ccd0', valid_till='2024-11-20 00:03:45', timestamp='2024-11-18 00:03:45')
# Processing trade order: TradeOrder(stock_name='CRM', price=1071.12, quantity=20, name='Willow', type='buy', order_id='00604bc0-8fb4-4712-b75b-c336ab72ccd0', valid_till='2024-11-20 00:03:45', timestamp='2024-11-18 00:03:45')
# CRM
# Trade order sent to orders: TradeOrder(stock_name='CRM', price=1071.12, quantity=20, name='Katherine', type='sell', order_id='00604bc0-8fb4-4712-b75b-c336ab72ccd0', valid_till='2024-11-20 00:03:45', timestamp='2024-11-18 00:03:45')
# Processing trade order: TradeOrder(stock_name='CRM', price=1071.12, quantity=20, name='Katherine', type='sell', order_id='00604bc0-8fb4-4712-b75b-c336ab72ccd0', valid_till='2024-11-20 00:03:45', timestamp='2024-11-18 00:03:45')
# CRM
# Trade order sent to orders: TradeOrder(stock_name='CRM', price=948.27, quantity=68, name='Yasmin', type='buy', order_id='c50185d9-1a98-4b92-af6b-b2e008b56692', valid_till='2024-11-19 00:03:55', timestamp='2024-11-18 00:03:55')
# Processing trade order: TradeOrder(stock_name='CRM', price=948.27, quantity=68, name='Yasmin', type='buy', order_id='c50185d9-1a98-4b92-af6b-b2e008b56692', valid_till='2024-11-19 00:03:55', timestamp='2024-11-18 00:03:55')
# CRM
# Trade order sent to orders: TradeOrder(stock_name='CRM', price=948.27, quantity=68, name='Rachel', type='sell', order_id='c50185d9-1a98-4b92-af6b-b2e008b56692', valid_till='2024-11-19 00:03:55', timestamp='2024-11-18 00:03:55')
# Processing trade order: TradeOrder(stock_name='CRM', price=948.27, quantity=68, name='Rachel', type='sell', order_id='c50185d9-1a98-4b92-af6b-b2e008b56692', valid_till='2024-11-19 00:03:55', timestamp='2024-11-18 00:03:55')
# BAC
# Trade order sent to orders: TradeOrder(stock_name='BAC', price=876.1, quantity=69, name='Harry', type='sell', order_id='bd30745f-afad-43df-83ac-8b540d1d7c0e', valid_till='2024-11-22 00:04:05', timestamp='2024-11-18 00:04:05')
# Processing trade order: TradeOrder(stock_name='BAC', price=876.1, quantity=69, name='Harry', type='sell', order_id='bd30745f-afad-43df-83ac-8b540d1d7c0e', valid_till='2024-11-22 00:04:05', timestamp='2024-11-18 00:04:05')
# BAC
# Trade order sent to orders: TradeOrder(stock_name='BAC', price=876.1, quantity=69, name='Sarah', type='buy', order_id='bd30745f-afad-43df-83ac-8b540d1d7c0e', valid_till='2024-11-22 00:04:05', timestamp='2024-11-18 00:04:05')
# Processing trade order: TradeOrder(stock_name='BAC', price=876.1, quantity=69, name='Sarah', type='buy', order_id='bd30745f-afad-43df-83ac-8b540d1d7c0e', valid_till='2024-11-22 00:04:05', timestamp='2024-11-18 00:04:05')
# TSLA
# Trade order sent to orders: TradeOrder(stock_name='TSLA', price=252.09, quantity=37, name='Riley', type='buy', order_id='cfa37b61-a62c-40eb-93fb-177978994394', valid_till='2024-11-22 00:04:15', timestamp='2024-11-18 00:04:15')
# Processing trade order: TradeOrder(stock_name='TSLA', price=252.09, quantity=37, name='Riley', type='buy', order_id='cfa37b61-a62c-40eb-93fb-177978994394', valid_till='2024-11-22 00:04:15', timestamp='2024-11-18 00:04:15')
# TSLA
# Trade order sent to orders: TradeOrder(stock_name='TSLA', price=252.09, quantity=37, name='Willow', type='sell', order_id='cfa37b61-a62c-40eb-93fb-177978994394', valid_till='2024-11-22 00:04:15', timestamp='2024-11-18 00:04:15')
# Processing trade order: TradeOrder(stock_name='TSLA', price=252.09, quantity=37, name='Willow', type='sell', order_id='cfa37b61-a62c-40eb-93fb-177978994394', valid_till='2024-11-22 00:04:15', timestamp='2024-11-18 00:04:15')
# LLY
# Trade order sent to orders: TradeOrder(stock_name='LLY', price=552.79, quantity=20, name='Sarah', type='sell', order_id='83276ed3-0ee7-4c60-8ebd-7810e210cb7c', valid_till='2024-11-21 00:04:25', timestamp='2024-11-18 00:04:25')
# Processing trade order: TradeOrder(stock_name='LLY', price=552.79, quantity=20, name='Sarah', type='sell', order_id='83276ed3-0ee7-4c60-8ebd-7810e210cb7c', valid_till='2024-11-21 00:04:25', timestamp='2024-11-18 00:04:25')
# TSLA
# Trade order sent to orders: TradeOrder(stock_name='TSLA', price=1120.44, quantity=39, name='David', type='sell', order_id='65009704-d572-4e51-ad01-3a2d67238eca', valid_till='2024-11-19 00:04:35', timestamp='2024-11-18 00:04:35')
# Processing trade order: TradeOrder(stock_name='TSLA', price=1120.44, quantity=39, name='David', type='sell', order_id='65009704-d572-4e51-ad01-3a2d67238eca', valid_till='2024-11-19 00:04:35', timestamp='2024-11-18 00:04:35')
# TSLA
# Trade order sent to orders: TradeOrder(stock_name='TSLA', price=1120.44, quantity=39, name='Frank', type='buy', order_id='65009704-d572-4e51-ad01-3a2d67238eca', valid_till='2024-11-19 00:04:35', timestamp='2024-11-18 00:04:35')
# Processing trade order: TradeOrder(stock_name='TSLA', price=1120.44, quantity=39, name='Frank', type='buy', order_id='65009704-d572-4e51-ad01-3a2d67238eca', valid_till='2024-11-19 00:04:35', timestamp='2024-11-18 00:04:35')
# JPM
# Trade order sent to orders: TradeOrder(stock_name='JPM', price=158.7, quantity=99, name='Thomas', type='buy', order_id='ed07edd2-aed8-4a56-9fc8-4b55ab72acdd', valid_till='2024-11-21 00:04:45', timestamp='2024-11-18 00:04:45')
# Processing trade order: TradeOrder(stock_name='JPM', price=158.7, quantity=99, name='Thomas', type='buy', order_id='ed07edd2-aed8-4a56-9fc8-4b55ab72acdd', valid_till='2024-11-21 00:04:45', timestamp='2024-11-18 00:04:45')
# JPM
# Trade order sent to orders: TradeOrder(stock_name='JPM', price=158.7, quantity=99, name='Eleanor', type='sell', order_id='ed07edd2-aed8-4a56-9fc8-4b55ab72acdd', valid_till='2024-11-21 00:04:45', timestamp='2024-11-18 00:04:45')
# Processing trade order: TradeOrder(stock_name='JPM', price=158.7, quantity=99, name='Eleanor', type='sell', order_id='ed07edd2-aed8-4a56-9fc8-4b55ab72acdd', valid_till='2024-11-21 00:04:45', timestamp='2024-11-18 00:04:45')
# Stopping producer.
